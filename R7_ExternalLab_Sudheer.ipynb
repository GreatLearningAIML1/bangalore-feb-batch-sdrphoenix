# %% [markdown]
# ### Build a DNN using Keras with `RELU` and `ADAM`

# %% [markdown]
# #### Load tensorflow

# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense,Dropout,Activation,Flatten

# %% [markdown]
# #### Collect Fashion mnist data from tf.keras.datasets

# %%
import keras
from tensorflow.keras.datasets import fashion_mnist
(x_train, y_train), (x_test, y_test) = fashion_mnist.load_data()

# %% [markdown]
# #### Change train and test labels into one-hot vectors

# %%
# convert class vectors to binary class matrices for keras
num_classes = 10
y_train = tf.keras.utils.to_categorical(y_train, num_classes)
y_test = tf.keras.utils.to_categorical(y_test, num_classes)

# %% [markdown]
# #### Build the Graph

# %% [markdown]
# #### Initialize model, reshape & normalize data

# %%
print('x_train shape =',x_train.shape)
print('y_train shape =',y_train.shape)
print('x_test shape =',x_test.shape)
print('y_test shape =',y_test.shape)
# Out:
# x_train shape = (60000, 28, 28)
# y_train shape = (60000, 10)
# x_test shape = (10000, 28, 28)
# y_test shape = (10000, 10)

# %%
# # normalize inputs from 0-255 to 0-1
x_train = x_train/255
x_test = x_test/255

# %%
x_train = x_train.reshape(60000,28,28,1)
x_test = x_test.reshape(10000,28,28,1)

# %%
model = tf.keras.Sequential([
    tf.keras.layers.Flatten(input_shape=(28, 28,1))
])

# %% [markdown]
# #### Add two fully connected layers with 200 and 100 neurons respectively with `relu` activations. Add a dropout layer with `p=0.25`

# %%
# Add Fully connected Layer with 200 neurons and relu activation
model.add(Dense(200,activation='relu'))

# Add Fully connected Layer with 100 neurons and relu activation
model.add(Dense(100,activation='relu'))

# Add Dropout layer
model.add(Dropout(0.25))

# %% [markdown]
# ### Add the output layer with a fully connected layer with 10 neurons with `softmax` activation. Use `categorical_crossentropy` loss and `adam` optimizer and train the network. And, report the final validation.

# %%
model.add(Dense(10, activation='softmax'))
# Compile model
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten (Flatten)            (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 200)               157000
# _________________________________________________________________
# dense_2 (Dense)              (None, 100)               20100
# _________________________________________________________________
# dropout (Dropout)            (None, 100)               0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                1010
# =================================================================
# Total params: 178,110
# Trainable params: 178,110
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Let us run and validate the model
model.fit(x_train, y_train, batch_size=32, epochs=20,validation_data=(x_test, y_test))
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.2600 - acc: 0.9015 - val_loss: 0.3454 - val_acc: 0.8835
# Epoch 2/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2525 - acc: 0.9042 - val_loss: 0.3542 - val_acc: 0.8792
# Epoch 3/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.2462 - acc: 0.9070 - val_loss: 0.3361 - val_acc: 0.8870
# Epoch 4/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.2375 - acc: 0.9106 - val_loss: 0.3273 - val_acc: 0.8894
# Epoch 5/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.2313 - acc: 0.9132 - val_loss: 0.3505 - val_acc: 0.8836
# Epoch 6/20
# 60000/60000 [==============================] - 6s 106us/sample - loss: 0.2270 - acc: 0.9149 - val_loss: 0.3424 - val_acc: 0.8857
# Epoch 7/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2215 - acc: 0.9156 - val_loss: 0.3391 - val_acc: 0.8892
# Epoch 8/20
# 60000/60000 [==============================] - 7s 111us/sample - loss: 0.2138 - acc: 0.9187 - val_loss: 0.3579 - val_acc: 0.8858
# Epoch 9/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2110 - acc: 0.9190 - val_loss: 0.3610 - val_acc: 0.8859
# Epoch 10/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2085 - acc: 0.9211 - val_loss: 0.3651 - val_acc: 0.8882
# Epoch 11/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.2025 - acc: 0.9233 - val_loss: 0.3603 - val_acc: 0.8873
# Epoch 12/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1936 - acc: 0.9259 - val_loss: 0.3756 - val_acc: 0.8903
# Epoch 13/20
# 60000/60000 [==============================] - 6s 107us/sample - loss: 0.1962 - acc: 0.9237 - val_loss: 0.3785 - val_acc: 0.8869
# Epoch 14/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1917 - acc: 0.9264 - val_loss: 0.3822 - val_acc: 0.8871
# Epoch 15/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1848 - acc: 0.9277 - val_loss: 0.3556 - val_acc: 0.8904
# Epoch 16/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1860 - acc: 0.9285 - val_loss: 0.3736 - val_acc: 0.8912
# Epoch 17/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1816 - acc: 0.9303 - val_loss: 0.4183 - val_acc: 0.8859
# Epoch 18/20
# 60000/60000 [==============================] - 6s 105us/sample - loss: 0.1754 - acc: 0.9328 - val_loss: 0.3798 - val_acc: 0.8910
# Epoch 19/20
# 60000/60000 [==============================] - 7s 115us/sample - loss: 0.1752 - acc: 0.9320 - val_loss: 0.3863 - val_acc: 0.8918
# Epoch 20/20
# 60000/60000 [==============================] - 7s 110us/sample - loss: 0.1702 - acc: 0.9348 - val_loss: 0.3900 - val_acc: 0.8898
