# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder, OneHotEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score
from sklearn.preprocessing import StandardScaler
import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.utils import to_categorical

# %%
# Read the dataset
df = pd.read_csv('/content/drive/My Drive/aiml/Residency7_AI/NNDL_Proj1/bank.csv')
df.head()
# Out:
#    RowNumber  CustomerId   Surname  ...  IsActiveMember EstimatedSalary Exited
# 0          1    15634602  Hargrave  ...               1       101348.88      1
# 1          2    15647311      Hill  ...               1       112542.58      0
# 2          3    15619304      Onio  ...               0       113931.57      1
# 3          4    15701354      Boni  ...               0        93826.63      0
# 4          5    15737888  Mitchell  ...               1        79084.10      0
#
# [5 rows x 14 columns]

# %%
# Drop the columns that are not required i.e., that do not contribute to prediction like Rownumber, CustomerID and Surname
df = df.drop(['RowNumber','CustomerId','Surname'],axis=1)
df.head()
# Out:
#    CreditScore Geography  Gender  ...  IsActiveMember  EstimatedSalary  Exited
# 0          619    France  Female  ...               1        101348.88       1
# 1          608     Spain  Female  ...               1        112542.58       0
# 2          502    France  Female  ...               0        113931.57       1
# 3          699    France  Female  ...               0         93826.63       0
# 4          850     Spain  Female  ...               1         79084.10       0
#
# [5 rows x 11 columns]

# %%
#Distinguish the feature and target set
X = df.iloc[:,0:10] # CreditScore to EstimatedSalary
y = df.iloc[:, 10] # Exited

# %%
X.head()
# Out:
#    CreditScore Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619    France  Female  ...          1               1        101348.88
# 1          608     Spain  Female  ...          0               1        112542.58
# 2          502    France  Female  ...          1               0        113931.57
# 3          699    France  Female  ...          0               0         93826.63
# 4          850     Spain  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
# Encoding categorical data (Geography Column)

le1 = LabelEncoder()
X.iloc[:,1] = le1.fit_transform(X.iloc[:,1])

# %%
X.head()
# Out:
#    CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619          0  Female  ...          1               1        101348.88
# 1          608          2  Female  ...          0               1        112542.58
# 2          502          0  Female  ...          1               0        113931.57
# 3          699          0  Female  ...          0               0         93826.63
# 4          850          2  Female  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
#Apply Label Encoding on Gender Column
le2 = LabelEncoder()
X.iloc[:, 2] = le2.fit_transform(X.iloc[:, 2])
X.head()
# Out:
#    CreditScore  Geography  Gender  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0          619          0       0  ...          1               1        101348.88
# 1          608          2       0  ...          0               1        112542.58
# 2          502          0       0  ...          1               0        113931.57
# 3          699          0       0  ...          0               0         93826.63
# 4          850          2       0  ...          1               1         79084.10
#
# [5 rows x 10 columns]

# %%
# Apply OneHotEncoding to Geography column so that model does not treat the Geography as Ordinal values
# One-hot encode categorical features and drop first value column
#no need to encode Gender, as there are only two categories

encoded = pd.DataFrame(to_categorical(X.iloc[:, 1]))

X = pd.concat([encoded, X], axis = 1)
X.head()
# Out:
#      0    1    2  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0  1.0  0.0  0.0  ...          1               1        101348.88
# 1  0.0  0.0  1.0  ...          0               1        112542.58
# 2  1.0  0.0  0.0  ...          1               0        113931.57
# 3  1.0  0.0  0.0  ...          0               0         93826.63
# 4  0.0  0.0  1.0  ...          1               1         79084.10
#
# [5 rows x 13 columns]

# %%
#Dropping the existing "Geography" column, and one of the onehotcoded columns.

X = X.drop([0,'Geography'], axis = 1)
X.head()
# Out:
#      1    2  CreditScore  ...  HasCrCard  IsActiveMember  EstimatedSalary
# 0  0.0  0.0          619  ...          1               1        101348.88
# 1  0.0  1.0          608  ...          0               1        112542.58
# 2  0.0  0.0          502  ...          1               0        113931.57
# 3  0.0  0.0          699  ...          0               0         93826.63
# 4  0.0  1.0          850  ...          1               1         79084.10
#
# [5 rows x 11 columns]

# %%
#Divide the data set into Train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 7)

# %%
# Apply Standard Scaling
sc = StandardScaler()
X_train = sc.fit_transform(X_train)
X_test = sc.transform(X_test)

# %%
# Build NNDL Model

#Initialize Model
model = Sequential()
#Input Layer
model.add(Dense(activation = 'relu', input_dim = 11, units=6, kernel_initializer='uniform'))
#Hidden Layer
model.add(Dense(activation = 'relu', units=6, kernel_initializer='uniform')) 
# Output Layer
model.add(Dense(activation = 'sigmoid', units=1, kernel_initializer='uniform'))

# %%
# Compile the Model
model.compile(optimizer='adam', loss = 'binary_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_4 (Dense)              (None, 6)                 72
# _________________________________________________________________
# dense_5 (Dense)              (None, 6)                 42
# _________________________________________________________________
# dense_6 (Dense)              (None, 1)                 7
# ...
# Total params: 121
# Trainable params: 121
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Model fitting
model.fit(X_train, y_train, batch_size=10, epochs=100)
# Out:
# Epoch 1/100
# 7000/7000 [==============================] - 1s 146us/step - loss: 0.4945 - acc: 0.7954
# Epoch 2/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4305 - acc: 0.7954
# Epoch 3/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4247 - acc: 0.7954
# Epoch 4/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4201 - acc: 0.8119
# Epoch 5/100
# 7000/7000 [==============================] - 1s 109us/step - loss: 0.4175 - acc: 0.8254
# Epoch 6/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4152 - acc: 0.8281
# Epoch 7/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4134 - acc: 0.8311
# Epoch 8/100
# 7000/7000 [==============================] - 1s 113us/step - loss: 0.4117 - acc: 0.8320
# Epoch 9/100
# 7000/7000 [==============================] - 1s 110us/step - loss: 0.4109 - acc: 0.8336
# Epoch 10/100
# ...

# %%
#Predict the results using 0.5 as a threshold 
y_pred = model.predict(X_test)
y_pred = (y_pred > 0.5)
print(y_pred)
# Out:
# [[False]
#  [False]
#  [False]
#  ...
#  [False]
#  [False]
#  [False]]

# %%
# Accuracy Score
print("Accuracy")
print(accuracy_score(y_test, y_pred))
# Out:
# Accuracy
# 0.8353333333333334

# %%
# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix")
print(cm)
# Out:
# Confusion Matrix
# [[2293  102]
#  [ 392  213]]
